# %% [markdown]
# # 线性回归的从零开始实现
# :label:`sec_linear_scratch`
#
# 在了解线性回归的关键思想之后，我们可以开始通过代码来动手实现线性回归了。
# 在这一节中，(**我们将从零开始实现整个方法，
# 包括数据流水线、模型、损失函数和小批量随机梯度下降优化器**)。
# 虽然现代的深度学习框架几乎可以自动化地进行所有这些工作，但从零开始实现可以确保我们真正知道自己在做什么。
# 同时，了解更细致的工作原理将方便我们自定义模型、自定义层或自定义损失函数。
# 在这一节中，我们将只使用张量和自动求导。
# 在之后的章节中，我们会充分利用深度学习框架的优势，介绍更简洁的实现方式。

# %%
#%conda list
# %conda install -c conda-forge onnx
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/aiscuser/microCanard01/.conda
#
#   added / updated specs:
#     - onnx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.1.0        |  py311hfdbb021_2         342 KB  conda-forge
#     cairo-1.16.0               |    h35add3b_1015         1.1 MB  conda-forge
#     cffi-1.17.1                |  py311hf29c0ef_0         295 KB  conda-forge
#     cudatoolkit-11.8.0         |      h4ba93d1_13       682.5 MB  conda-forge
#     ffmpeg-4.4.0               |       h6987444_4         9.9 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     glib-2.82.2                |       h44428e9_0         589 KB  conda-forge
#     glib-tools-2.82.2          |       h4833e2c_0         111 KB  conda-forge
#     gnutls-3.6.13              |       h85f3911_1         2.0 MB  conda-forge
#     harfbuzz-7.3.0             |       hdb3a94d_0         1.4 MB  conda-forge
#     icu-72.1                   |       hcb278e6_0        11.4 MB  conda-forge
#     lcms2-2.14                 |       h6ed2654_0         256 KB  conda-forge
#     leptonica-1.82.0           |       h74f16a4_2         2.7 MB  conda-forge
#     libabseil-20240722.0       | cxx17_hbbce691_2         1.2 MB  conda-forge
#     libarchive-3.6.2           |       h039dbb9_1         824 KB  conda-forge
#     libblas-3.9.0              |16_linux64_openblas          13 KB  conda-forge
#     libcblas-3.9.0             |16_linux64_openblas          13 KB  conda-forge
#     libdeflate-1.14            |       h166bdaf_0          81 KB  conda-forge
#     libexpat-2.6.4             |       h5888daf_0          72 KB  conda-forge
#     libglib-2.82.2             |       h2ff4ddf_0         3.7 MB  conda-forge
#     libiconv-1.17              |       hd590300_2         689 KB  conda-forge
#     liblapack-3.9.0            |16_linux64_openblas          13 KB  conda-forge
#     libpng-1.6.44              |       hadc24fc_0         284 KB  conda-forge
#     libprotobuf-5.28.2         |       h5b01275_0         2.8 MB  conda-forge
#     libsqlite-3.45.2           |       h2797004_0         837 KB  conda-forge
#     libtiff-4.4.0              |       h82bc61c_5         473 KB  conda-forge
#     libtorch-2.5.1             |cpu_generic_h1b269f6_7        50.9 MB  conda-forge
#     libuv-1.49.2               |       hb9d3cd8_0         864 KB  conda-forge
#     libvpx-1.11.0              |       h9c3ff4c_3         1.1 MB  conda-forge
#     libxcb-1.13                |    h7f98852_1004         391 KB  conda-forge
#     libxml2-2.11.5             |       h0d562d8_0         688 KB  conda-forge
#     lzo-2.10                   |    hd590300_1001         167 KB  conda-forge
#     nettle-3.6                 |       he412f7d_0         6.5 MB  conda-forge
#     onnx-1.17.0                |  py311h7e27cf4_1        10.4 MB  conda-forge
#     openjpeg-2.5.0             |       h7d73246_1         533 KB  conda-forge
#     pcre2-10.44                |       hba22ea6_2         930 KB  conda-forge
#     pillow-9.2.0               |  py311h9461556_3        45.5 MB  conda-forge
#     protobuf-5.28.2            |  py311hfdbb021_0         462 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     python-3.11.8              |hab00c5b_0_cpython        29.3 MB  conda-forge
#     pytorch-2.5.1              |cpu_generic_py311_h1482152_7        36.2 MB  conda-forge
#     requests-2.32.3            |     pyhd8ed1ab_1          57 KB  conda-forge
#     sleef-3.7                  |       h1b44611_2         1.8 MB  conda-forge
#     sqlite-3.45.2              |       h2c6b66d_0         829 KB  conda-forge
#     tesseract-5.3.1            |       he1868e8_0       167.9 MB  conda-forge
#     torchvision-0.15.2         |cuda118py311h4cc2eb7_0        10.3 MB
#     x264-1!161.3030            |       h7f98852_1         2.5 MB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xorg-kbproto-1.0.7         |    hb9d3cd8_1003          30 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.5           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.4          |       h0b41bf4_0         810 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h0b41bf4_2          49 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h7f98852_1003          32 KB  conda-forge
#     xorg-renderproto-0.11.1    |    hb9d3cd8_1003          12 KB  conda-forge
#     xorg-xextproto-7.3.0       |    hb9d3cd8_1004          30 KB  conda-forge
#     xorg-xproto-7.0.31         |    hb9d3cd8_1008          72 KB  conda-forge
#     zstandard-0.23.0           |  py311hbc35293_1         408 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.07 GB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      conda-forge/linux-64::brotli-python-1.1.0-py311hfdbb021_2
#   certifi            conda-forge/noarch::certifi-2024.12.14-pyhd8ed1ab_0
#   cffi               conda-forge/linux-64::cffi-1.17.1-py311hf29c0ef_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.4.0-pyhd8ed1ab_1
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.8.0-h4ba93d1_13
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   h2                 conda-forge/noarch::h2-4.1.0-pyhd8ed1ab_1
#   hpack              conda-forge/noarch::hpack-4.0.0-pyhd8ed1ab_1
#   hyperframe         conda-forge/noarch::hyperframe-6.0.1-pyhd8ed1ab_1
#   idna               conda-forge/noarch::idna-3.10-pyhd8ed1ab_1
#   libblas            conda-forge/linux-64::libblas-3.9.0-16_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-16_linux64_openblas
#   libexpat           conda-forge/linux-64::libexpat-2.6.4-h5888daf_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-16_linux64_openblas
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.45.2-h2797004_0
#   libtorch           conda-forge/linux-64::libtorch-2.5.1-cpu_generic_h1b269f6_7
#   libuv              conda-forge/linux-64::libuv-1.49.2-hb9d3cd8_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.3.1-hb9d3cd8_2
#   lzo                conda-forge/linux-64::lzo-2.10-hd590300_1001
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   nomkl              conda-forge/noarch::nomkl-1.0-h5ca1d4c_0
#   onnx               conda-forge/linux-64::onnx-1.17.0-py311h7e27cf4_1
#   protobuf           conda-forge/linux-64::protobuf-5.28.2-py311hfdbb021_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pycparser          conda-forge/noarch::pycparser-2.22-pyh29332c3_1
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha55dd90_7
#   requests           conda-forge/noarch::requests-2.32.3-pyhd8ed1ab_1
#   sleef              conda-forge/linux-64::sleef-3.7-h1b44611_2
#   urllib3            conda-forge/noarch::urllib3-2.3.0-pyhd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!161.3030-h7f98852_1
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-hb9d3cd8_1003
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.5-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.4-h0b41bf4_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-hb9d3cd8_1003
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-hb9d3cd8_1004
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-hb9d3cd8_1008
#   zstandard          conda-forge/linux-64::zstandard-0.23.0-py311hbc35293_1
#
# The following packages will be UPDATED:
#
#   cairo                  pkgs/main::cairo-1.16.0-hb05425b_5 --> conda-forge::cairo-1.16.0-h35add3b_1015
#   fontconfig         pkgs/main::fontconfig-2.14.1-h55d465d~ --> conda-forge::fontconfig-2.15.0-h7e30c49_1
#   freetype            pkgs/main::freetype-2.12.1-h4a9f257_0 --> conda-forge::freetype-2.12.1-h267a509_2
#   glib                    pkgs/main::glib-2.78.4-h6a678d5_0 --> conda-forge::glib-2.82.2-h44428e9_0
#   glib-tools         pkgs/main::glib-tools-2.78.4-h6a678d5~ --> conda-forge::glib-tools-2.82.2-h4833e2c_0
#   harfbuzz             pkgs/main::harfbuzz-4.3.0-hf52aaf7_2 --> conda-forge::harfbuzz-7.3.0-hdb3a94d_0
#   libabseil          pkgs/main::libabseil-20240116.2-cxx17~ --> conda-forge::libabseil-20240722.0-cxx17_hbbce691_2
#   libglib              pkgs/main::libglib-2.78.4-hdc74915_0 --> conda-forge::libglib-2.82.2-h2ff4ddf_0
#   libiconv              pkgs/main::libiconv-1.16-h5eee18b_3 --> conda-forge::libiconv-1.17-hd590300_2
#   libpng                pkgs/main::libpng-1.6.39-h5eee18b_0 --> conda-forge::libpng-1.6.44-hadc24fc_0
#   libprotobuf        pkgs/main::libprotobuf-4.25.3-he621ea~ --> conda-forge::libprotobuf-5.28.2-h5b01275_0
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-11.2.0-h12345~ --> conda-forge::libstdcxx-ng-14.2.0-h4852527_1
#   libuuid              pkgs/main::libuuid-1.41.5-h5eee18b_0 --> conda-forge::libuuid-2.38.1-h0b41bf4_0
#   pcre2                   pkgs/main::pcre2-10.42-hebb0a14_1 --> conda-forge::pcre2-10.44-hba22ea6_2
#   pytorch            pkgs/main::pytorch-2.3.1-cpu_py311h4f~ --> conda-forge::pytorch-2.5.1-cpu_generic_py311_h1482152_7
#   tesseract           pkgs/main::tesseract-5.2.0-h6a678d5_2 --> conda-forge::tesseract-5.3.1-he1868e8_0
#   zlib                    pkgs/main::zlib-1.2.13-h5eee18b_1 --> conda-forge::zlib-1.3.1-hb9d3cd8_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ffmpeg                 pkgs/main::ffmpeg-6.1.1-he32514a_1 --> conda-forge::ffmpeg-4.4.0-h6987444_4
#   icu                        pkgs/main::icu-73.1-h6a678d5_0 --> conda-forge::icu-72.1-hcb278e6_0
#   lcms2                    pkgs/main::lcms2-2.16-hb9589c4_0 --> conda-forge::lcms2-2.14-h6ed2654_0
#   leptonica          pkgs/main::leptonica-1.82.0-h42c8aad_2 --> conda-forge::leptonica-1.82.0-h74f16a4_2
#   libarchive         pkgs/main::libarchive-3.7.7-hfab0078_0 --> conda-forge::libarchive-3.6.2-h039dbb9_1
#   libdeflate          pkgs/main::libdeflate-1.22-h5eee18b_0 --> conda-forge::libdeflate-1.14-h166bdaf_0
#   libtiff               pkgs/main::libtiff-4.5.1-hffd6297_1 --> conda-forge::libtiff-4.4.0-h82bc61c_5
#   libvpx                pkgs/main::libvpx-1.13.1-h6a678d5_0 --> conda-forge::libvpx-1.11.0-h9c3ff4c_3
#   libxcb                  pkgs/main::libxcb-1.15-h7f8727e_0 --> conda-forge::libxcb-1.13-h7f98852_1004
#   libxml2              pkgs/main::libxml2-2.13.5-hfdd30dd_0 --> conda-forge::libxml2-2.11.5-h0d562d8_0
#   openjpeg             pkgs/main::openjpeg-2.5.2-he7f1fd0_0 --> conda-forge::openjpeg-2.5.0-h7d73246_1
#   pillow             pkgs/main::pillow-11.0.0-py311hcea889~ --> conda-forge::pillow-9.2.0-py311h9461556_3
#   python               pkgs/main::python-3.11.11-he870216_0 --> conda-forge::python-3.11.8-hab00c5b_0_cpython
#   sqlite                pkgs/main::sqlite-3.45.3-h5eee18b_0 --> conda-forge::sqlite-3.45.2-h2c6b66d_0
#   tk                        pkgs/main::tk-8.6.14-h39e8969_0 --> conda-forge::tk-8.6.13-noxft_h4845f30_101
#   zstd                     pkgs/main::zstd-1.5.6-hc292b87_0 --> conda-forge::zstd-1.5.6-ha6fb4c9_0
#
# The following packages will be DOWNGRADED:
#
#   torchvision                    0.18.1-cpu_py311h54128f0_0 --> 0.15.2-cuda118py311h4cc2eb7_0
#
#
#
# Downloading and Extracting Packages:
# cudatoolkit-11.8.0   | 682.5 MB  |                                       |   0%
# tesseract-5.3.1      | 167.9 MB  |                                       |   0%
#
# libtorch-2.5.1       | 50.9 MB   |                                       |   0%
#
#
# pillow-9.2.0         | 45.5 MB   |                                       |   0%
#
#
#
# pytorch-2.5.1        | 36.2 MB   |                                       |   0%
#
#
#
#
# python-3.11.8        | 29.3 MB   |                                       |   0%
#
#
#
#
#
# icu-72.1             | 11.4 MB   |                                       |   0%
#
#
#
#
#
#
# onnx-1.17.0          | 10.4 MB   |                                       |   0%
#
#
#
#
#
#
#
# torchvision-0.15.2   | 10.3 MB   |                                       |   0%
#
#
#
#
#
#
#
#
# ffmpeg-4.4.0         | 9.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# nettle-3.6           | 6.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# leptonica-1.82.0     | 2.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!161.3030      | 2.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.13        | 2.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.7            | 1.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-7.3.0       | 1.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20240722.0 | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.11.0        | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | 1                                     |   0% [A
#
# libtorch-2.5.1       | 50.9 MB   | #4                                    |   4%
#
#
# pillow-9.2.0         | 45.5 MB   |                                       |   0%
# cudatoolkit-11.8.0   | 682.5 MB  | 3                                     |   1%
#
#
#
# pytorch-2.5.1        | 36.2 MB   |                                       |   0%
#
# libtorch-2.5.1       | 50.9 MB   | ####8                                 |  13%
#
#
# pillow-9.2.0         | 45.5 MB   | ##9                                   |   8%
# cudatoolkit-11.8.0   | 682.5 MB  | 6                                     |   2%
#
#
#
# pytorch-2.5.1        | 36.2 MB   | 3                                     |   1%
#
# libtorch-2.5.1       | 50.9 MB   | #######5                              |  20%
#
#
# pillow-9.2.0         | 45.5 MB   | #####9                                |  16%
# cudatoolkit-11.8.0   | 682.5 MB  | 8                                     |   2%
#
# libtorch-2.5.1       | 50.9 MB   | ##########3                           |  28%
#
#
#
# pytorch-2.5.1        | 36.2 MB   | #                                     |   3%
#
#
# pillow-9.2.0         | 45.5 MB   | ########8                             |  24%
# cudatoolkit-11.8.0   | 682.5 MB  | #                                     |   3%
#
# libtorch-2.5.1       | 50.9 MB   | #############1                        |  36%
#
#
#
# pytorch-2.5.1        | 36.2 MB   | ###                                   |   8%
#
#
# pillow-9.2.0         | 45.5 MB   | ###########9                          |  32%
# tesseract-5.3.1      | 167.9 MB  | ###1                                  |   8%
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #2                                    |   3%
#
#
# pillow-9.2.0         | 45.5 MB   | ##############7                       |  40%
#
# libtorch-2.5.1       | 50.9 MB   | ###############9                      |  43%
# tesseract-5.3.1      | 167.9 MB  | ###8                                  |  10%
#
#
#
# pytorch-2.5.1        | 36.2 MB   | #########4                            |  25%
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #4                                    |   4%
#
# libtorch-2.5.1       | 50.9 MB   | ##################4                   |  50%
# tesseract-5.3.1      | 167.9 MB  | ####4                                 |  12%
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #6                                    |   4%
#
#
# pillow-9.2.0         | 45.5 MB   | ####################1                 |  54%
#
# libtorch-2.5.1       | 50.9 MB   | #####################1                |  57%
# tesseract-5.3.1      | 167.9 MB  | #####2                                |  14%
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #8                                    |   5%
#
#
# pillow-9.2.0         | 45.5 MB   | ######################7               |  62%
#
# libtorch-2.5.1       | 50.9 MB   | #######################9              |  65%
# tesseract-5.3.1      | 167.9 MB  | ######                                |  16%
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | ##                                    |   6%
#
#
# pillow-9.2.0         | 45.5 MB   | #########################5            |  69%
#
# libtorch-2.5.1       | 50.9 MB   | ##########################6           |  72%
# tesseract-5.3.1      | 167.9 MB  | ######8                               |  18%
#
#
#
# pytorch-2.5.1        | 36.2 MB   | ########################7             |  67%
#
# cudatoolkit-11.8.0   | 682.5 MB  | ##2                                   |   6%
#
#
# pillow-9.2.0         | 45.5 MB   | ############################1         |  76%
# tesseract-5.3.1      | 167.9 MB  | #######5                              |  21%
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | ##4                                   |   7%
#
#
# pillow-9.2.0         | 45.5 MB   | ##############################7       |  83%
#
# libtorch-2.5.1       | 50.9 MB   | ###############################9      |  86%
# tesseract-5.3.1      | 167.9 MB  | ########3                             |  23%
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | ##6                                   |   7%
#
#
# pillow-9.2.0         | 45.5 MB   | #################################3    |  90%
#
# libtorch-2.5.1       | 50.9 MB   | ##################################4   |  93%
# tesseract-5.3.1      | 167.9 MB  | #########                             |  25%
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | ##8                                   |   8%
#
#
# pillow-9.2.0         | 45.5 MB   | ####################################1 |  98%
# cudatoolkit-11.8.0   | 682.5 MB  | ###1                                  |   8%
# cudatoolkit-11.8.0   | 682.5 MB  | ###3                                  |   9%
# cudatoolkit-11.8.0   | 682.5 MB  | ###6                                  |  10%
# cudatoolkit-11.8.0   | 682.5 MB  | ###9                                  |  11%
# cudatoolkit-11.8.0   | 682.5 MB  | ####1                                 |  11%
# cudatoolkit-11.8.0   | 682.5 MB  | ####4                                 |  12%
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | ####8                                 |  13%
# tesseract-5.3.1      | 167.9 MB  | ################9                     |  46%
#
#
#
#
# python-3.11.8        | 29.3 MB   | ####2                                 |  12%
# cudatoolkit-11.8.0   | 682.5 MB  | #####                                 |  14%
#
#
#
#
# python-3.11.8        | 29.3 MB   | ########5                             |  23%
# tesseract-5.3.1      | 167.9 MB  | ##################8                   |  51%
#
#
#
#
#
# icu-72.1             | 11.4 MB   |                                       |   0%
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #####3                                |  14%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #######9                              |  22%
#
#
#
#
#
#
# onnx-1.17.0          | 10.4 MB   |                                       |   0%
# tesseract-5.3.1      | 167.9 MB  | ###################6                  |  53%
#
#
#
#
# python-3.11.8        | 29.3 MB   | ###############1                      |  41%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##############8                       |  40%
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #####5                                |  15%
#
#
#
#
# python-3.11.8        | 29.3 MB   | ##################1                   |  49%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #####################3                |  58%
#
#
#
#
#
#
# onnx-1.17.0          | 10.4 MB   | ##############5                       |  39%
# tesseract-5.3.1      | 167.9 MB  | ####################4                 |  55%
#
#
#
#
# python-3.11.8        | 29.3 MB   | #####################1                |  57%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ############################7         |  78%
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #####7                                |  16%
# tesseract-5.3.1      | 167.9 MB  | #####################1                |  57%
#
#
#
#
# python-3.11.8        | 29.3 MB   | ########################              |  65%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###################################4  |  96%
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #####9                                |  16%
#
#
#
#
# python-3.11.8        | 29.3 MB   | ##########################9           |  73%
# cudatoolkit-11.8.0   | 682.5 MB  | ######                                |  16%
#
#
#
#
# python-3.11.8        | 29.3 MB   | ##############################3       |  82%
# tesseract-5.3.1      | 167.9 MB  | ######################2               |  60%
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | ######2                               |  17%
# tesseract-5.3.1      | 167.9 MB  | ######################8               |  62%
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | ######3                               |  17%
# cudatoolkit-11.8.0   | 682.5 MB  | ######5                               |  18%
# cudatoolkit-11.8.0   | 682.5 MB  | ######6                               |  18%
#
#
#
#
#
#
#
# torchvision-0.15.2   | 10.3 MB   |                                       |   0%
# tesseract-5.3.1      | 167.9 MB  | ########################7             |  67%
#
#
#
#
#
#
#
#
# ffmpeg-4.4.0         | 9.9 MB    |                                       |   0%
#
#
#
#
#
#
#
# torchvision-0.15.2   | 10.3 MB   | ######4                               |  17%
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | ######8                               |  19%
# tesseract-5.3.1      | 167.9 MB  | #########################3            |  69%
#
#
#
#
#
#
#
# torchvision-0.15.2   | 10.3 MB   | ##############2                       |  38%
#
#
#
#
#
#
#
#
# ffmpeg-4.4.0         | 9.9 MB    | ###############5                      |  42%
# cudatoolkit-11.8.0   | 682.5 MB  | ######9                               |  19%
#
#
#
#
#
#
#
# torchvision-0.15.2   | 10.3 MB   | #######################5              |  64%
#
#
#
#
#
#
#
#
# ffmpeg-4.4.0         | 9.9 MB    | #######################8              |  64%
# cudatoolkit-11.8.0   | 682.5 MB  | #######1                              |  19%
#
#
#
#
#
#
#
# torchvision-0.15.2   | 10.3 MB   | ###############################6      |  86%
#
#
#
#
#
#
#
#
# ffmpeg-4.4.0         | 9.9 MB    | ################################      |  87%
# cudatoolkit-11.8.0   | 682.5 MB  | #######2                              |  20%
# cudatoolkit-11.8.0   | 682.5 MB  | #######4                              |  20%
# cudatoolkit-11.8.0   | 682.5 MB  | #######5                              |  20%
# cudatoolkit-11.8.0   | 682.5 MB  | #######7                              |  21%
# tesseract-5.3.1      | 167.9 MB  | #############################6        |  80%
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #######9                              |  21%
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
# nettle-3.6           | 6.5 MB    | #############6                        |  37%
# cudatoolkit-11.8.0   | 682.5 MB  | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | ############################8         |  78%
#
#
#
#
#
#
#
#
#
# nettle-3.6           | 6.5 MB    | ###########################5          |  75%
# cudatoolkit-11.8.0   | 682.5 MB  | ########2                             |  22%
# cudatoolkit-11.8.0   | 682.5 MB  | ########3                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.8 MB    | 2                                     |   1%
# cudatoolkit-11.8.0   | 682.5 MB  | ########5                             |  23%
# cudatoolkit-11.8.0   | 682.5 MB  | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!161.3030      | 2.5 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# leptonica-1.82.0     | 2.7 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.13        | 2.0 MB    | 2                                     |   1%
# cudatoolkit-11.8.0   | 682.5 MB  | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# leptonica-1.82.0     | 2.7 MB    | #######3                              |  20%
# cudatoolkit-11.8.0   | 682.5 MB  | #########                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# leptonica-1.82.0     | 2.7 MB    | #######################8              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.7            | 1.8 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 3                                     |   1%
# cudatoolkit-11.8.0   | 682.5 MB  | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-7.3.0       | 1.4 MB    | 4                                     |   1%
# cudatoolkit-11.8.0   | 682.5 MB  | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20240722.0 | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.11.0        | 1.1 MB    | 5                                     |   1%
# cudatoolkit-11.8.0   | 682.5 MB  | #########4                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | #########6                            |  26% [A
# cudatoolkit-11.8.0   | 682.5 MB  | ####################################8 | 100%
#
#
# pillow-9.2.0         | 45.5 MB   | ##################################### | 100%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##################################### | 100%
#
# libtorch-2.5.1       | 50.9 MB   | ##################################### | 100%
#
# libtorch-2.5.1       | 50.9 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# ffmpeg-4.4.0         | 9.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# torchvision-0.15.2   | 10.3 MB   | ##################################### | 100%
#
#
#
# pytorch-2.5.1        | 36.2 MB   | ##################################### | 100%
#
#
#
#
# python-3.11.8        | 29.3 MB   | ##################################### | 100%
#
#
#
#
#
#
# onnx-1.17.0          | 10.4 MB   | ##################################### | 100%
#
#
#
#
#
#
# onnx-1.17.0          | 10.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!161.3030      | 2.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!161.3030      | 2.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# nettle-3.6           | 6.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.7            | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.7            | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# leptonica-1.82.0     | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# leptonica-1.82.0     | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.13        | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.13        | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.11.0        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.11.0        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-7.3.0       | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-7.3.0       | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20240722.0 | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20240722.0 | 1.2 MB    | ##################################### | 100%
# cudatoolkit-11.8.0   | 682.5 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: | By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#%matplotlib inline
import random
import torch
from d2l import torch as d2l

# %% [markdown]
# ## 生成数据集
#
# 为了简单起见，我们将[**根据带有噪声的线性模型构造一个人造数据集。**]
# 我们的任务是使用这个有限样本的数据集来恢复这个模型的参数。
# 我们将使用低维数据，这样可以很容易地将其可视化。
# 在下面的代码中，我们生成一个包含1000个样本的数据集，
# 每个样本包含从标准正态分布中采样的2个特征。
# 我们的合成数据集是一个矩阵$\mathbf{X}\in \mathbb{R}^{1000 \times 2}$。
#
# (**我们使用线性模型参数$\mathbf{w} = [2, -3.4]^\top$、$b = 4.2$
# 和噪声项$\epsilon$生成数据集及其标签：
#
# $$\mathbf{y}= \mathbf{X} \mathbf{w} + b + \mathbf\epsilon.$$
# **)
#
# $\epsilon$可以视为模型预测和标签时的潜在观测误差。
# 在这里我们认为标准假设成立，即$\epsilon$服从均值为0的正态分布。
# 为了简化问题，我们将标准差设为0.01。
# 下面的代码生成合成数据集。

# %%
def synthetic_data(w, b, num_examples):  #@save
    """生成y=Xw+b+噪声"""
    X = torch.normal(0, 1, (num_examples, len(w)))
    y = torch.matmul(X, w) + b
    y += torch.normal(0, 0.01, y.shape)
    return X, y.reshape((-1, 1))

# %%
true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)

# %% [markdown]
# 注意，[**`features`中的每一行都包含一个二维数据样本，
# `labels`中的每一行都包含一维标签值（一个标量）**]。

# %%
print('features:', features[0],'\nlabel:', labels[0])
# Out:
# features: tensor([-1.8700,  0.1846])
# label: tensor([-0.1645])

# %% [markdown]
# 通过生成第二个特征`features[:, 1]`和`labels`的散点图，
# 可以直观观察到两者之间的线性关系。

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (1)].detach().numpy(), labels.detach().numpy(), 1);

# %% [markdown]
# ## 读取数据集
#
# 回想一下，训练模型时要对数据集进行遍历，每次抽取一小批量样本，并使用它们来更新我们的模型。
# 由于这个过程是训练机器学习算法的基础，所以有必要定义一个函数，
# 该函数能打乱数据集中的样本并以小批量方式获取数据。
#
# 在下面的代码中，我们[**定义一个`data_iter`函数，
# 该函数接收批量大小、特征矩阵和标签向量作为输入，生成大小为`batch_size`的小批量**]。
# 每个小批量包含一组特征和标签。

# %%
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    # 这些样本是随机读取的，没有特定的顺序
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size):
        batch_indices = torch.tensor(
            indices[i: min(i + batch_size, num_examples)])
        yield features[batch_indices], labels[batch_indices]

# %% [markdown]
# 通常，我们利用GPU并行运算的优势，处理合理大小的“小批量”。
# 每个样本都可以并行地进行模型计算，且每个样本损失函数的梯度也可以被并行计算。
# GPU可以在处理几百个样本时，所花费的时间不比处理一个样本时多太多。
#
# 我们直观感受一下小批量运算：读取第一个小批量数据样本并打印。
# 每个批量的特征维度显示批量大小和输入特征数。
# 同样的，批量的标签形状与`batch_size`相等。

# %%
batch_size = 10

for X, y in data_iter(batch_size, features, labels):
    print(X, '\n', y)
    break
# Out:
# tensor([[ 0.3934,  2.5705],
#         [ 0.5849, -0.7124],
#         [ 0.1008,  0.6947],
#         [-0.4493, -0.9037],
#         [ 2.3104, -0.2798],
#         [-0.0173, -0.2552],
#         [ 0.1963, -0.5445],
#         [-1.0580, -0.5180],
#         [ 0.8417, -1.5547],
#         [-0.6316,  0.9732]])
#  tensor([[-3.7623],
#         [ 7.7852],
#         [ 2.0443],
#         [ 6.3767],
#         [ 9.7776],
#         [ 5.0301],
#         [ 6.4541],
#         [ 3.8407],
#         [11.1396],
#         [-0.3836]])

# %% [markdown]
# 当我们运行迭代时，我们会连续地获得不同的小批量，直至遍历完整个数据集。
# 上面实现的迭代对教学来说很好，但它的执行效率很低，可能会在实际问题上陷入麻烦。
# 例如，它要求我们将所有数据加载到内存中，并执行大量的随机内存访问。
# 在深度学习框架中实现的内置迭代器效率要高得多，
# 它可以处理存储在文件中的数据和数据流提供的数据。
#
# ## 初始化模型参数
#
# [**在我们开始用小批量随机梯度下降优化我们的模型参数之前**]，
# (**我们需要先有一些参数**)。
# 在下面的代码中，我们通过从均值为0、标准差为0.01的正态分布中采样随机数来初始化权重，
# 并将偏置初始化为0。

# %%
w = torch.normal(0, 0.01, size=(2,1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %% [markdown]
# 在初始化参数之后，我们的任务是更新这些参数，直到这些参数足够拟合我们的数据。
# 每次更新都需要计算损失函数关于模型参数的梯度。
# 有了这个梯度，我们就可以向减小损失的方向更新每个参数。
# 因为手动计算梯度很枯燥而且容易出错，所以没有人会手动计算梯度。
# 我们使用 :numref:`sec_autograd`中引入的自动微分来计算梯度。
#
# ## 定义模型
#
# 接下来，我们必须[**定义模型，将模型的输入和参数同模型的输出关联起来。**]
# 回想一下，要计算线性模型的输出，
# 我们只需计算输入特征$\mathbf{X}$和模型权重$\mathbf{w}$的矩阵-向量乘法后加上偏置$b$。
# 注意，上面的$\mathbf{Xw}$是一个向量，而$b$是一个标量。
# 回想一下 :numref:`subsec_broadcasting`中描述的广播机制：
# 当我们用一个向量加一个标量时，标量会被加到向量的每个分量上。

# %%
def linreg(X, w, b):  #@save
    """线性回归模型"""
    return torch.matmul(X, w) + b

# %% [markdown]
# ## [**定义损失函数**]
#
# 因为需要计算损失函数的梯度，所以我们应该先定义损失函数。
# 这里我们使用 :numref:`sec_linear_regression`中描述的平方损失函数。
# 在实现中，我们需要将真实值`y`的形状转换为和预测值`y_hat`的形状相同。

# %%
def squared_loss(y_hat, y):  #@save
    """均方损失"""
    return (y_hat - y.reshape(y_hat.shape)) ** 2 / 2

# %% [markdown]
# ## (**定义优化算法**)
#
# 正如我们在 :numref:`sec_linear_regression`中讨论的，线性回归有解析解。
# 尽管线性回归有解析解，但本书中的其他模型却没有。
# 这里我们介绍小批量随机梯度下降。
#
# 在每一步中，使用从数据集中随机抽取的一个小批量，然后根据参数计算损失的梯度。
# 接下来，朝着减少损失的方向更新我们的参数。
# 下面的函数实现小批量随机梯度下降更新。
# 该函数接受模型参数集合、学习速率和批量大小作为输入。每
# 一步更新的大小由学习速率`lr`决定。
# 因为我们计算的损失是一个批量样本的总和，所以我们用批量大小（`batch_size`）
# 来规范化步长，这样步长大小就不会取决于我们对批量大小的选择。

# %%
def sgd(params, lr, batch_size):  #@save
    """小批量随机梯度下降"""
    with torch.no_grad():
        for param in params:
            param -= lr * param.grad / batch_size
            param.grad.zero_()

# %% [markdown]
# ## 训练
#
# 现在我们已经准备好了模型训练所有需要的要素，可以实现主要的[**训练过程**]部分了。
# 理解这段代码至关重要，因为从事深度学习后，
# 相同的训练过程几乎一遍又一遍地出现。
# 在每次迭代中，我们读取一小批量训练样本，并通过我们的模型来获得一组预测。
# 计算完损失后，我们开始反向传播，存储每个参数的梯度。
# 最后，我们调用优化算法`sgd`来更新模型参数。
#
# 概括一下，我们将执行以下循环：
#
# * 初始化参数
# * 重复以下训练，直到完成
#     * 计算梯度$\mathbf{g} \leftarrow \partial_{(\mathbf{w},b)} \frac{1}{|\mathcal{B}|} \sum_{i \in \mathcal{B}} l(\mathbf{x}^{(i)}, y^{(i)}, \mathbf{w}, b)$
#     * 更新参数$(\mathbf{w}, b) \leftarrow (\mathbf{w}, b) - \eta \mathbf{g}$
#
# 在每个*迭代周期*（epoch）中，我们使用`data_iter`函数遍历整个数据集，
# 并将训练数据集中所有样本都使用一次（假设样本数能够被批量大小整除）。
# 这里的迭代周期个数`num_epochs`和学习率`lr`都是超参数，分别设为3和0.03。
# 设置超参数很棘手，需要通过反复试验进行调整。
# 我们现在忽略这些细节，以后会在 :numref:`chap_optimization`中详细介绍。

# %%
lr = 0.03
num_epochs = 3
net = linreg
loss = squared_loss

# %%
for epoch in range(num_epochs):
    for X, y in data_iter(batch_size, features, labels):
        l = loss(net(X, w, b), y)  # X和y的小批量损失
        # 因为l形状是(batch_size,1)，而不是一个标量。l中的所有元素被加到一起，
        # 并以此计算关于[w,b]的梯度
        l.sum().backward()
        sgd([w, b], lr, batch_size)  # 使用参数的梯度更新参数
    with torch.no_grad():
        train_l = loss(net(features, w, b), labels)
        print(f'epoch {epoch + 1}, loss {float(train_l.mean()):f}')
# Out:
# epoch 1, loss 0.042790
# epoch 2, loss 0.000162
# epoch 3, loss 0.000051

# %% [markdown]
# 因为我们使用的是自己合成的数据集，所以我们知道真正的参数是什么。
# 因此，我们可以通过[**比较真实参数和通过训练学到的参数来评估训练的成功程度**]。
# 事实上，真实参数和通过训练学到的参数确实非常接近。

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([-1.3804e-04,  5.7936e-05], grad_fn=<SubBackward0>)
# b的估计误差: tensor([0.0006], grad_fn=<RsubBackward1>)

# %% [markdown]
# 注意，我们不应该想当然地认为我们能够完美地求解参数。
# 在机器学习中，我们通常不太关心恢复真正的参数，而更关心如何高度准确预测参数。
# 幸运的是，即使是在复杂的优化问题上，随机梯度下降通常也能找到非常好的解。
# 其中一个原因是，在深度网络中存在许多参数组合能够实现高度精确的预测。
#
# ## 小结
#
# * 我们学习了深度网络是如何实现和优化的。在这一过程中只使用张量和自动微分，不需要定义层或复杂的优化器。
# * 这一节只触及到了表面知识。在下面的部分中，我们将基于刚刚介绍的概念描述其他模型，并学习如何更简洁地实现其他模型。
#
# ## 练习
#
# 1. 如果我们将权重初始化为零，会发生什么。算法仍然有效吗？
# 1. 假设试图为电压和电流的关系建立一个模型。自动微分可以用来学习模型的参数吗?
# 1. 能基于[普朗克定律](https://en.wikipedia.org/wiki/Planck%27s_law)使用光谱能量密度来确定物体的温度吗？
# 1. 计算二阶导数时可能会遇到什么问题？这些问题可以如何解决？
# 1. 为什么在`squared_loss`函数中需要使用`reshape`函数？
# 1. 尝试使用不同的学习率，观察损失函数值下降的快慢。
# 1. 如果样本个数不能被批量大小整除，`data_iter`函数的行为会有什么变化？

# %% [markdown]
# [Discussions](https://discuss.d2l.ai/t/1778)
